# %%
# This notebook is used to load the generations from the json files
# and output them to check the generations
import json

# Load the generations from the json files
with open('/n/netscratch/ydu_lab/Lab/alex/LMVF/math_500/gen/0/task_10_solutions.json', 'r') as f:
    generations = json.load(f)

# %%
# Show the keys of the generations
for k in generations[0].keys():
    print(k)
# Out:
# problem
# level
# type
# solution
# gt_answer
# generated_solutions_gemma-3-1b-it
# generated_answers_gemma-3-1b-it
# generated_solutions_Qwen2.5-0.5B-Instruct
# generated_answers_Qwen2.5-0.5B-Instruct
# generated_solutions_Qwen2.5-1.5B-Instruct
# generated_answers_Qwen2.5-1.5B-Instruct
# generated_solutions_Qwen2.5-3B-Instruct
# generated_answers_Qwen2.5-3B-Instruct
# generated_solutions_Qwen2-0.5B-Instruct
# generated_answers_Qwen2-0.5B-Instruct
# ver_resp_Qwen2.5-3B-Instruct_on_gemma-3-1b-it
# ver_resp_Qwen2.5-3B-Instruct_on_Qwen2.5-0.5B-Instruct
# ver_resp_Qwen2.5-3B-Instruct_on_Qwen2.5-1.5B-Instruct
# ver_resp_Qwen2.5-3B-Instruct_on_Qwen2.5-3B-Instruct
# ver_resp_Qwen2.5-3B-Instruct_on_Qwen2-0.5B-Instruct
# ver_resp_deepseek-r1-distill-qwen-1.5b_on_gemma-3-1b-it
# ver_resp_deepseek-r1-distill-qwen-1.5b_on_Qwen2.5-0.5B-Instruct
# ver_resp_deepseek-r1-distill-qwen-1.5b_on_Qwen2.5-1.5B-Instruct
# ver_resp_deepseek-r1-distill-qwen-1.5b_on_Qwen2.5-3B-Instruct
# ...

# %%
generations[0]['fin_ver_approval_bools_{strict_ver_model_name}_on_ver_{ver_model_name}_on_{gen_model_name}'][0]
# Out:
# [False, True, False, False, False, False]

# %%
problem_num = 0 
# gen_num = 3

print(len(generations[problem_num]['ver_resp_deepseek-r1-distill-qwen-1.5b_on_gemma-3-1b-it']))
# Out:
# 1

# %%
print(generations[problem_num]['generated_answers_Qwen2.5-0.5B-Instruct'][gen_num])
# Out:
# None

# %%
# This notebook is used to load the generations from the json files
# and output them to check the generations
import json

# Load the generations from the json files
with open('/n/netscratch/ydu_lab/Lab/alex/LMVF/math_500/gen/task_0_solutions_trial_1.json', 'r') as f:
    generations = json.load(f)

# %%
# Show the keys of the generations
for k in generations[0].keys():
    print(k)
# Out:
# problem
# level
# type
# solution
# gt_answer
# generated_solutions_Qwen2.5-0.5B-Instruct
# generated_answers_Qwen2.5-0.5B-Instruct
# generated_solutions_Qwen2.5-1.5B-Instruct
# generated_answers_Qwen2.5-1.5B-Instruct
# generated_solutions_Qwen2.5-3B-Instruct
# generated_answers_Qwen2.5-3B-Instruct
# generated_solutions_Qwen2.5-7B-Instruct
# generated_answers_Qwen2.5-7B-Instruct

# %%
problem_num = 0 
gen_num = 3

print(generations[problem_num]['generated_solutions_Qwen2.5-0.5B-Instruct'][gen_num])
# Out:
# To convert the point \((0, 3)\) from rectangular coordinates to polar coordinates, we need to use the formulas for converting between rectangular and polar coordinates. The formulas are as follows:
#
# 1. \( r = \sqrt{x^2 + y^2} \)
# 2. \( \theta = \tan^{-1}\left(\frac{y}{x}\right) \)
#
# Given the point \((0, 3)\), we have \( x = 0 \) and \( y = 3 \).
#
# First, calculate \( r \):
#
# \[
# r = \sqrt{x^2 + y^2} = \sqrt{0^2 + 3^2} = \sqrt{9} = 3
# \]
#
# Next, calculate \( \theta \):
#
# \[
# \theta = \tan^{-1}\left(\frac{y}{x}\right) = \tan^{-1}\left(\frac{3}{0}\right)
# \]
#
# However, division by zero is undefined in mathematics. This means that the point \((0, 3)\) lies on the vertical axis (where \( y = 3 \)), which corresponds to an angle of \(0\) radians or \(0^\circ\). Therefore, the correct conversion should be:
#
# \[
# \theta = 0
# \]
#
# Thus, the polar coordinates of the point \((0, 3)\) are:
#
# \[
# (r, \theta) = (3, 0)
# \]

# %%
print(generations[problem_num]['generated_answers_Qwen2.5-0.5B-Instruct'][gen_num])
# Out:
# None
